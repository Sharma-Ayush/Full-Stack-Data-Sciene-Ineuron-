# %% [markdown]
# # Python Basics - Assignment_1

# %% [markdown]
# # Question 1:

# %% [raw]
# In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [markdown]
# # Answer 1:

# %% [raw]
# * -> none
# 'hello' -> both
# -87.8 -> both
# - -> none
# / -> none
# + -> none
# 6 -> both
# A value by itself is also an expression in python and operators itself cannot be an expression as it doesnt evaluate to any value. We can even try the built in function eval() to evaluate any expression and giving operator as an input eval("*") will give syntax error.

# %% [markdown]
# # Question 2:

# %% [raw]
# What is the difference between string and variable?

# %% [markdown]
# # Answer 2:

# %% [raw]
# String:
# String is a built-in data type in python which is used to store sequence of characters as data by enclosing the sequence within single, double or triple quotes. It is an immutable data type.
#
# Variable:
# Variables in python are named references that are attached to objects created in memory. These varaibles names can be used as aliases for accessing the value and processing it. It is basically a means of storing data and attaching some name to it for further use in our programs.

# %% [markdown]
# # Question 3:

# %% [raw]
# Describe three different data types.

# %% [markdown]
# # Answer 3:

# %% [raw]
# Int:
# It is a built-in data type which is used to represent data consisting of whole numbers only. Pyhton supports giving of integer data input in different base formats as well, like decimal, binary, octadecimal and hexadecimal but internally it always stores it in decimal format. It is immutable in nature.
#
# Dictionary:
# It is a built-in data type in python which is used to store data in form of key-value pairs. There is no associated sequence of data within a dictionary as we see indexing in lists. Keys are unique and are used to acces the associated values. It is represented by data enclosed within curly brackets in form of key-value pair and is a mutable data type.
#
# List:
# It is a built-in data type in python which is used to store a collection of homogeneous or heterogeneours type of data
# within it. It is represented by data enclosed within square brackets. The order of data within a list is fixed and indices starting from 0 can be used to access parts of data. It is a mutable data type.

# %% [markdown]
# # Question 4:

# %% [raw]
# What is an expression made up of? What do all expressions do?

# %% [markdown]
# # Answer 4

# %% [raw]
# An expression can be made up of operators, identifiers, function calls or data literals.
# An expression is something that evaluates to some value. Even a data value itself is an expression as it evaluates to itself, this is a simple expression. More complex expressions contain combinations of opreators, function calls and operands which compute to some value.

# %% [markdown]
# # Question 5:

# %% [raw]
# This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# # Answer 5:

# %% [raw]
# An expression is something which evaluates or computes to some value while statement is a python instruction to do something whether it computes to a value or just does something while not returning anything. spam = 10 is an assignment statement which says python to assign an integer object with value 10 to variable spam.

# %% [markdown]
# # Question 6:

# %% [raw]
# After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# # Answer 6:

# %% [raw]
# bacon is stil containing 22, as the last line didn't change the value of bacon. Last line was an expression that just computed some value and didnt assign anything to bacon.

# %% [markdown]
# # Question 7:

# %% [raw]
# What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3

# %% [markdown]
# # Answer 7:

# %% [raw]
# First line -> 'spamspamspam'
# Second line -> 'spamspamspam'

# %% [markdown]
# # Question 8:

# %% [raw]
# Why is eggs a valid variable name while 100 is invalid?

# %% [markdown]
# # Answer 8:

# %% [raw]
# Python has a naming convention for declaring any identifier in python. Its name can contain alaphabets, underscores and digits but it should always start with an underscore or an alphabet and should not be a reserved keyword. Thus, eggs is valid variable name while 100 is an invalid identifer name as it starts with a digit and rather it represents a data literal of type int.
